# %%
import pandas as pd
import numpy as np

# Definir los nombres de las columnas
Variables= ['cod_reg', 'cod_dep', 'cod_loc', 'pad', 'block', 'EP', 'uni', 'sup_predio','sup_edificada', 'V_cat_terreno',
            'V_cat_mejoras',  'V_cat_total', 'V_impuestos', 'Fecha_UDJ', 'Vigencia_UDJ']  

# Especificar los tipos de datos para las columnas
dtypes = {
    'cod_reg': str,
    'cod_dep': str,
    'cod_loc': str,  # O str, dependiendo de tus datos
    'pad': int,
    'block': str,
    'EP': str,
    'uni': int,
    'sup_predio': int,
    'sup_edificada': int,
    'V_cat_terreno': int,
    'V_cat_mejoras': int,
    'V_cat_total': int,
    'V_impuestos': int,
    'Fecha_UDJ': bool,
    'Vigencia_UDJ': bool
}

# Leer el archivo CSV y asignar los nombres a las columnas
P_Urbanos = pd.read_csv('C:/Users/macar/Desktop/Archivos Python/Padrones Urbanos.csv', sep=',', encoding='cp1252', header=None, names=Variables, dtype={4: str, 5: str}  )

# Mostrar las primeras filas del archivo
P_Urbanos.head(8)
# Out:
#   cod_reg cod_dep cod_loc  pad block   EP  uni  sup_predio  sup_edificada  \
# 0      CO       A      AA    1   NaN  NaN    0        1473            438
# 1      CO       A      AA    2   NaN  NaN    0         246            112
# 2      CO       A      AA    3   NaN  NaN    0         123             99
# 3      CO       A      AA    4   NaN  NaN    0         234             54
# 4      CO       A      AA    6   NaN  NaN    0         505             75
# 5      CO       A      AA   10   NaN  NaN    0         462            283
# 6      CO       A      AA   11   NaN  NaN    0         440            139
# 7      CO       A      AA   12   NaN  NaN    0         470            152
#
#    V_cat_terreno  V_cat_mejoras  V_cat_total  V_impuestos Fecha_UDJ  \
# 0         396202        1644448      2040650      2040650      /  /
# 1         149880         640149       790029       790029      /  /
# 2          70630         489035       559665       559665      /  /
# 3         132215         220728       352943       352943      /  /
# 4         274276         431225       705501       705501      /  /
# 5         303908        1339819      1643727      1643727      /  /
# 6         290376         584098       874474       874474      /  /
# 7         308792         454518       763310       763310      /  /
#
#   Vigencia_UDJ
# 0         /  /
# 1         /  /
# 2         /  /
# 3         /  /
# 4         /  /
# 5         /  /
# 6         /  /
# 7         /  /

# %%
P_Urbanos.shape
# Out:
# (1485862, 15)

# %%
# Filtrar filas donde 'cod_dep' es igual a 'V' que es Montevideo
filtro_dep = P_Urbanos[P_Urbanos['cod_dep'] == 'V']


# Mostrar el DataFrame filtrado
filtro_dep.head()
# Out:
#        cod_reg cod_dep cod_loc  pad block   EP  uni  sup_predio  \
# 812667      CO       V      AA    5   NaN  NaN    0         130
# 812668      CO       V      AA    7   NaN  NaN    0         206
# 812669      CO       V      AA    8   NaN  NaN    0         175
# 812670      CO       V      AA    9   NaN  NaN    0         171
# 812671      CO       V      AA   14   NaN  NaN    0         196
#
#         sup_edificada  V_cat_terreno  V_cat_mejoras  V_cat_total  V_impuestos  \
# 812667            138         669500         374348      1043848      1043848
# 812668            168         873257         319436      1192693      1192693
# 812669            341         596274        3670770      4267044      4267044
# 812670            143         583071         543110      1126181      1126181
# 812671            303         893558         325618      1219176      1219176
#
#          Fecha_UDJ Vigencia_UDJ
# 812667        /  /         /  /
# 812668        /  /         /  /
# 812669  28/11/2018   28/11/2023
# 812670        /  /         /  /
# 812671        /  /         /  /

# %%
filtro_dep.shape
# Out:
# (510298, 15)

# %%
# Eliminar los apartamentos duplicados y quedarte solo con un registro por padrón
filtro_dep = filtro_dep.drop_duplicates(subset='pad').reset_index(drop=True)

# Mostrar el DataFrame filtrado
filtro_dep.head()
# Out:
#   cod_reg cod_dep cod_loc  pad block   EP  uni  sup_predio  sup_edificada  \
# 0      CO       V      AA    5   NaN  NaN    0         130            138
# 1      CO       V      AA    7   NaN  NaN    0         206            168
# 2      CO       V      AA    8   NaN  NaN    0         175            341
# 3      CO       V      AA    9   NaN  NaN    0         171            143
# 4      CO       V      AA   14   NaN  NaN    0         196            303
#
#    V_cat_terreno  V_cat_mejoras  V_cat_total  V_impuestos   Fecha_UDJ  \
# 0         669500         374348      1043848      1043848        /  /
# 1         873257         319436      1192693      1192693        /  /
# 2         596274        3670770      4267044      4267044  28/11/2018
# 3         583071         543110      1126181      1126181        /  /
# 4         893558         325618      1219176      1219176        /  /
#
#   Vigencia_UDJ
# 0         /  /
# 1         /  /
# 2   28/11/2023
# 3         /  /
# 4         /  /

# %%
#CUantas filas tiene el archivo
num_filas = filtro_dep.shape[0]

print(num_filas)
# Out:
# 200177

# %%
# Reemplazar cadenas vacías o '/  /' por NaN
filtro_dep['Fecha_UDJ'] = filtro_dep['Fecha_UDJ'].replace(['', '/  /'], pd.NA)

# Separar la columna 'Fecha' en tres nuevas columnas, manejando valores NaN
filtro_dep[['dia', 'mes', 'anio']] = filtro_dep['Fecha_UDJ'].str.split('/', expand=True)

# Convertir las nuevas columnas a tipo entero, usando fillna para evitar errores
filtro_dep['dia'] = filtro_dep['dia'].astype('Int64')  # 'Int64' permite valores NA
filtro_dep['mes'] = filtro_dep['mes'].astype('Int64')
filtro_dep['anio'] = filtro_dep['anio'].astype('Int64')

# Mostrar el DataFrame resultante
filtro_dep.head()
# Out:
#   cod_reg cod_dep cod_loc  pad block   EP  uni  sup_predio  sup_edificada  \
# 0      CO       V      AA    5   NaN  NaN    0         130            138
# 1      CO       V      AA    7   NaN  NaN    0         206            168
# 2      CO       V      AA    8   NaN  NaN    0         175            341
# 3      CO       V      AA    9   NaN  NaN    0         171            143
# 4      CO       V      AA   14   NaN  NaN    0         196            303
#
#    V_cat_terreno  V_cat_mejoras  V_cat_total  V_impuestos   Fecha_UDJ  \
# 0         669500         374348      1043848      1043848        <NA>
# 1         873257         319436      1192693      1192693        <NA>
# 2         596274        3670770      4267044      4267044  28/11/2018
# 3         583071         543110      1126181      1126181        <NA>
# 4         893558         325618      1219176      1219176        <NA>
#
#   Vigencia_UDJ   dia   mes  anio
# 0         /  /  <NA>  <NA>  <NA>
# 1         /  /  <NA>  <NA>  <NA>
# 2   28/11/2023    28    11  2018
# 3         /  /  <NA>  <NA>  <NA>
# 4         /  /  <NA>  <NA>  <NA>

# %%
# Ver los tipos de datos de cada columna
tipos_datos = filtro_dep.dtypes

# Mostrar los tipos de datos
print(tipos_datos)
# Out:
# cod_reg          object
# cod_dep          object
# cod_loc          object
# pad               int64
# block            object
# EP               object
# uni               int64
# sup_predio        int64
# sup_edificada     int64
# V_cat_terreno     int64
# V_cat_mejoras     int64
# V_cat_total       int64
# V_impuestos       int64
# Fecha_UDJ        object
# Vigencia_UDJ     object
# dia               Int64
# mes               Int64
# anio              Int64
# dtype: object

# %%
# Contar la cantidad de registros por año
conteo_por_anio = filtro_dep.groupby('anio').size().reset_index(name='cantidad_registros')

print(conteo_por_anio)
# Out:
#     anio  cantidad_registros
# 0    203                   1
# 1    403                   1
# 2    603                   1
# 3   1997                   1
# 4   2001                   5
# 5   2002                 279
# 6   2003                 862
# 7   2004                1680
# 8   2005                1416
# 9   2006                1457
# 10  2007                1780
# 11  2008                2319
# 12  2009                2081
# 13  2010                2644
# 14  2011                3130
# 15  2012                2484
# 16  2013                2786
# 17  2014                2606
# 18  2015                2578
# 19  2016                2615
# 20  2017                3189
# 21  2018                2834
# 22  2019                2915
# 23  2020                2695
# 24  2021                3260
# 25  2022                6510
# 26  2023                6699
# 27  2024                4456

# %%
#Permisos Intendencia Montevideo
# Leer el archivo CSV y asignar los nombres a las columnas
Permisos = pd.read_csv('C:/Users/macar/Desktop/Archivos Python/permisos_construccion.csv', sep=';')

Permisos.rename(columns={'padron': 'pad'}, inplace=True)
# Mostrar las primeras filas del archivo
Permisos.head()
# Out:
#    pad                                            destino    area  \
# 0    2  Vivienda                                      ...   26.00
# 1    8  Comercio                                      ...  315.00
# 2    8  Comercio                                      ...    5.00
# 3    9  Vivienda                                      ...   14.84
# 4   15  Vivienda                                      ...   49.85
#
#                                                calle  puerta  letra  anio  \
# 0  MIGUELETE                                     ...  1420.0         2000
# 1  LA PAZ                                        ...  1439.0         2013
# 2  LA PAZ                                        ...  1439.0         2019
# 3  LA PAZ                                        ...  1431.0         1998
# 4  PIEDRA ALTA                                   ...  1779.0         2004
#
#    mes           expediente             tipo_obra
# 0    9       4113-016778-00            Obra Nueva
# 1    7       4113-007575-13            Obra Nueva
# 2    3  2018-4113-98-001306  Regularizacion - Año
# 3   12       4113-016126-98               Reforma
# 4    3       4113-014456-00  Modificacion en Obra

# %%
# Ver los tipos de datos de cada columna
tipos_datos = Permisos.dtypes

# Mostrar los tipos de datos
print(tipos_datos)
# Out:
# pad             int64
# destino        object
# area          float64
# calle          object
# puerta        float64
# letra          object
# anio            int64
# mes             int64
# expediente     object
# tipo_obra      object
# dtype: object

# %%
#Crear en permisos la variable cod_dep
Permisos['cod_dep'] = 'V'
Permisos.head()
# Out:
#    pad                                            destino    area  \
# 0    2  Vivienda                                      ...   26.00
# 1    8  Comercio                                      ...  315.00
# 2    8  Comercio                                      ...    5.00
# 3    9  Vivienda                                      ...   14.84
# 4   15  Vivienda                                      ...   49.85
#
#                                                calle  puerta  letra  anio  \
# 0  MIGUELETE                                     ...  1420.0         2000
# 1  LA PAZ                                        ...  1439.0         2013
# 2  LA PAZ                                        ...  1439.0         2019
# 3  LA PAZ                                        ...  1431.0         1998
# 4  PIEDRA ALTA                                   ...  1779.0         2004
#
#    mes           expediente             tipo_obra cod_dep
# 0    9       4113-016778-00            Obra Nueva       V
# 1    7       4113-007575-13            Obra Nueva       V
# 2    3  2018-4113-98-001306  Regularizacion - Año       V
# 3   12       4113-016126-98               Reforma       V
# 4    3       4113-014456-00  Modificacion en Obra       V

# %%
# Supongamos que 'resultado' es tu DataFrame que contiene los conteos        ### ESto lo eliminaría, no aporta nada
# Calcular la suma total de 'conteo_destino'
conteo_pad = Permisos['pad'].count()

# Mostrar la suma total
print(f"Suma total de conteo_pad: {conteo_pad}")
# Out:
# Suma total de conteo_pad: 39511

# %%
#CUantas filas tiene el archivo                                             ### también lo eliminaría
num_filas = Permisos.shape[0]

print(Permisos)
# Out:
#           pad                                            destino    area  \
# 0           2  Vivienda                                      ...   26.00
# 1           8  Comercio                                      ...  315.00
# 2           8  Comercio                                      ...    5.00
# 3           9  Vivienda                                      ...   14.84
# 4          15  Vivienda                                      ...   49.85
# ...       ...                                                ...     ...
# 39506  436935  Vivienda                                      ...   46.40
# 39507  436935  Vivienda                                      ...   54.70
# 39508  952223  Vivienda                                      ...    8.76
# 39509  952223  Vivienda                                      ...    5.24
# 39510  952223  Vivienda                                      ...  215.00
#
#                                                    calle  puerta  letra  anio  \
# 0      MIGUELETE                                     ...  1420.0         2000
# 1      LA PAZ                                        ...  1439.0         2013
# 2      LA PAZ                                        ...  1439.0         2019
# 3      LA PAZ                                        ...  1431.0         1998
# 4      PIEDRA ALTA                                   ...  1779.0         2004
# ...                                                  ...     ...    ...   ...
# 39506                                                ...     NaN         1999
# 39507                                                ...     NaN         1999
# 39508                                                ...     NaN         2011
# 39509                                                ...     NaN         2011
# 39510                                                ...     NaN         2011
#
#        mes           expediente             tipo_obra cod_dep
# 0        9       4113-016778-00            Obra Nueva       V
# 1        7       4113-007575-13            Obra Nueva       V
# 2        3  2018-4113-98-001306  Regularizacion - Año       V
# 3       12       4113-016126-98               Reforma       V
# 4        3       4113-014456-00  Modificacion en Obra       V
# ...    ...                  ...                   ...     ...
# 39506    3       4113-022067-98           Desconocido       V
# 39507    3       4113-022067-98  Regularizacion - Año       V
# 39508    2       4113-000547-11            Obra Nueva       V
# 39509    2       4113-000547-11               Reforma       V
# 39510    2       4113-000547-11  Regularizacion - Año       V
#
# [39511 rows x 11 columns]

# %%
### VEr el shape directamente para saber cantidad de filas y columnas
Permisos.shape
# Out:
# (39511, 11)

# %%
# Ordenar el DataFrame por Padron (ascendente), anio, mes, area en orden descendente me quedo con el ùltimo permiso aprobado para ese padron y el area màs grande de esa fecha.
Permisos_ordenado = Permisos.sort_values(by=['pad','anio', 'mes', 'area'], ascending=[True,False, False, False])

# Mostrar el DataFrame ordenado
Permisos_ordenado.head(15)
# Out:
#     pad                                            destino    area  \
# 0     2  Vivienda                                      ...   26.00
# 2     8  Comercio                                      ...    5.00
# 1     8  Comercio                                      ...  315.00
# 3     9  Vivienda                                      ...   14.84
# 4    15  Vivienda                                      ...   49.85
# 6    27  Comercio                                      ...  284.00
# 5    27  Comercio                                      ...  320.00
# 8    32  Comercio                                      ...  353.00
# 7    32  Comercio                                      ...   36.00
# 9    43  Vivienda,Comercio,Otros                       ...  147.00
# 10   43  Vivienda,Comercio,Otros                       ...   59.00
# 11   43  Vivienda,Comercio,Otros                       ...   33.00
# 12   52  Vivienda                                      ...   50.00
# 13   53  Comercio                                      ...  388.00
# 14   63  Vivienda                                      ...  146.21
#
#                                                 calle  puerta  letra  anio  \
# 0   MIGUELETE                                     ...  1420.0         2000
# 2   LA PAZ                                        ...  1439.0         2019
# 1   LA PAZ                                        ...  1439.0         2013
# 3   LA PAZ                                        ...  1431.0         1998
# 4   PIEDRA ALTA                                   ...  1779.0         2004
# 6   LA PAZ                                        ...  1461.0         2021
# 5   LA PAZ                                        ...  1461.0         2014
# 8   PIEDRA ALTA                                   ...  1771.0         2008
# 7   PIEDRA ALTA                                   ...  1771.0         2008
# 9   MINAS                                         ...  1803.0         2022
# 10  MINAS                                         ...  1803.0         2022
# 11  MINAS                                         ...  1803.0         2022
# 12  LA PAZ                                        ...  1577.0         2005
# 13  LA PAZ                                        ...  1581.0         2019
# 14  MIGUELETE                                     ...  1576.0         1999
#
#     mes           expediente              tipo_obra cod_dep
# 0     9       4113-016778-00             Obra Nueva       V
# 2     3  2018-4113-98-001306   Regularizacion - Año       V
# 1     7       4113-007575-13             Obra Nueva       V
# 3    12       4113-016126-98                Reforma       V
# 4     3       4113-014456-00   Modificacion en Obra       V
# 6     9  2021-4113-98-000660  Reforma a Regularizar       V
# 5     9  2016-4118-98-000212             Obra Nueva       V
# 8     4  2016-4113-98-001655   Regularizacion - Año       V
# 7     4  2016-4113-98-001655             Obra Nueva       V
# 9    11  2022-4113-98-001048   Incorporacion A.P.H.       V
# 10   11  2022-4113-98-001048                Reforma       V
# 11   11  2022-4113-98-001048  Reforma a Regularizar       V
# 12    2       4113-000339-05                Reforma       V
# 13    4  2018-4113-98-001100                Reforma       V
# 14    4       4113-022109-98   Incorporacion A.P.H.       V

# %%
# Primero, eliminamos duplicados por padròn para quedarnos con el ùtimo registro en año para ese padròn.

p_sin_duplicados = Permisos_ordenado.drop_duplicates(subset=['pad','anio','mes'])

p_sin_duplicados.head(15)
# Out:
#     pad                                            destino     area  \
# 0     2  Vivienda                                      ...    26.00
# 2     8  Comercio                                      ...     5.00
# 1     8  Comercio                                      ...   315.00
# 3     9  Vivienda                                      ...    14.84
# 4    15  Vivienda                                      ...    49.85
# 6    27  Comercio                                      ...   284.00
# 5    27  Comercio                                      ...   320.00
# 8    32  Comercio                                      ...   353.00
# 9    43  Vivienda,Comercio,Otros                       ...   147.00
# 12   52  Vivienda                                      ...    50.00
# 13   53  Comercio                                      ...   388.00
# 14   63  Vivienda                                      ...   146.21
# 16   67  Comercio                                      ...   121.00
# 18   69  Vivienda                                      ...   438.00
# 17   69  Vivienda,Otros                                ...  1414.00
#
#                                                 calle  puerta  letra  anio  \
# 0   MIGUELETE                                     ...  1420.0         2000
# 2   LA PAZ                                        ...  1439.0         2019
# 1   LA PAZ                                        ...  1439.0         2013
# 3   LA PAZ                                        ...  1431.0         1998
# 4   PIEDRA ALTA                                   ...  1779.0         2004
# 6   LA PAZ                                        ...  1461.0         2021
# 5   LA PAZ                                        ...  1461.0         2014
# 8   PIEDRA ALTA                                   ...  1771.0         2008
# 9   MINAS                                         ...  1803.0         2022
# 12  LA PAZ                                        ...  1577.0         2005
# 13  LA PAZ                                        ...  1581.0         2019
# 14  MIGUELETE                                     ...  1576.0         1999
# 16  MIGUELETE                                     ...  1552.0         2011
# 18  MINAS                                         ...  1836.0         2023
# 17  MINAS                                         ...  1836.0         2022
#
#     mes           expediente              tipo_obra cod_dep
# 0     9       4113-016778-00             Obra Nueva       V
# 2     3  2018-4113-98-001306   Regularizacion - Año       V
# 1     7       4113-007575-13             Obra Nueva       V
# 3    12       4113-016126-98                Reforma       V
# 4     3       4113-014456-00   Modificacion en Obra       V
# 6     9  2021-4113-98-000660  Reforma a Regularizar       V
# 5     9  2016-4118-98-000212             Obra Nueva       V
# 8     4  2016-4113-98-001655   Regularizacion - Año       V
# 9    11  2022-4113-98-001048   Incorporacion A.P.H.       V
# 12    2       4113-000339-05                Reforma       V
# 13    4  2018-4113-98-001100                Reforma       V
# 14    4       4113-022109-98   Incorporacion A.P.H.       V
# 16    8       4113-010849-11                Reforma       V
# 18    9  2023-4113-98-000574             Obra Nueva       V
# 17    2  2022-4113-98-000041             Obra Nueva       V

# %%
# Contar cuántos registros hay por 'anio' y 'mes'
resultado = p_sin_duplicados.groupby(['anio', 'mes']).size().reset_index(name ='conteo_destino')


# Mostrar el resultado
print(resultado)
# Out:
#      anio  mes  conteo_destino
# 0    1997   11               1
# 1    1997   12              18
# 2    1998    1              23
# 3    1998    2              47
# 4    1998    3              42
# ..    ...  ...             ...
# 316  2024    4              61
# 317  2024    5              44
# 318  2024    6              25
# 319  2024    7              42
# 320  2024    8              47
#
# [321 rows x 3 columns]

# %%
# Contar la cantidad de registros por año
p_conteo_por_anio = p_sin_duplicados.groupby('anio').size().reset_index(name='cantidad_registros')

print(p_conteo_por_anio)
# Out:
#     anio  cantidad_registros
# 0   1997                  19
# 1   1998                1044
# 2   1999                1237
# 3   2000                1088
# 4   2001                 655
# 5   2002                 688
# 6   2003                 986
# 7   2004                1115
# 8   2005                1358
# 9   2006                1224
# 10  2007                1309
# 11  2008                1430
# 12  2009                1340
# 13  2010                1330
# 14  2011                1249
# 15  2012                1156
# 16  2013                1071
# 17  2014                1169
# 18  2015                1003
# 19  2016                 662
# 20  2017                 963
# 21  2018                 794
# 22  2019                 798
# 23  2020                 559
# 24  2021                 706
# 25  2022                 784
# 26  2023                 626
# 27  2024                 316

# %%
# Supongamos que 'resultado' es tu DataFrame que contiene los conteos
# Calcular la suma total de 'conteo_destino'
suma_conteo_destino = resultado['conteo_destino'].sum()

# Mostrar la suma total
print(f"Suma total de conteo_destino: {suma_conteo_destino}")
# Out:
# Suma total de conteo_destino: 26679

# %%
# Machear los DataFrames usando un left join
cat_per = pd.merge(filtro_dep, Permisos, on=['anio','mes','pad'], how='left')

# Machear los DataFrames usando un left join
per_cat = pd.merge(p_sin_duplicados,filtro_dep, on=['anio','mes','pad'], how='left')

# %%
#Mostrar el primer Dataframe resultante
cat_per.head()
# Out:
#   cod_reg cod_dep_x cod_loc  pad block   EP  uni  sup_predio  sup_edificada  \
# 0      CO         V      AA    5   NaN  NaN    0         130            138
# 1      CO         V      AA    7   NaN  NaN    0         206            168
# 2      CO         V      AA    8   NaN  NaN    0         175            341
# 3      CO         V      AA    9   NaN  NaN    0         171            143
# 4      CO         V      AA   14   NaN  NaN    0         196            303
#
#    V_cat_terreno  ...   mes  anio  destino area calle  puerta  letra  \
# 0         669500  ...  <NA>  <NA>      NaN  NaN   NaN     NaN    NaN
# 1         873257  ...  <NA>  <NA>      NaN  NaN   NaN     NaN    NaN
# 2         596274  ...    11  2018      NaN  NaN   NaN     NaN    NaN
# 3         583071  ...  <NA>  <NA>      NaN  NaN   NaN     NaN    NaN
# 4         893558  ...  <NA>  <NA>      NaN  NaN   NaN     NaN    NaN
#
#    expediente tipo_obra  cod_dep_y
# 0         NaN       NaN        NaN
# 1         NaN       NaN        NaN
# 2         NaN       NaN        NaN
# 3         NaN       NaN        NaN
# 4         NaN       NaN        NaN
#
# [5 rows x 26 columns]

# %%
#Mostrar cantidad de filas y columnas del primer Dataframe resultante
cat_per.shape
# Out:
# (200882, 26)

# %%
#Mosstrar el segundo Dataframe resultante
per_cat.head()
# Out:
#    pad                                            destino    area  \
# 0    2  Vivienda                                      ...   26.00
# 1    8  Comercio                                      ...    5.00
# 2    8  Comercio                                      ...  315.00
# 3    9  Vivienda                                      ...   14.84
# 4   15  Vivienda                                      ...   49.85
#
#                                                calle  puerta  letra  anio  \
# 0  MIGUELETE                                     ...  1420.0         2000
# 1  LA PAZ                                        ...  1439.0         2019
# 2  LA PAZ                                        ...  1439.0         2013
# 3  LA PAZ                                        ...  1431.0         1998
# 4  PIEDRA ALTA                                   ...  1779.0         2004
#
#    mes           expediente             tipo_obra  ... uni sup_predio  \
# 0    9       4113-016778-00            Obra Nueva  ... NaN        NaN
# 1    3  2018-4113-98-001306  Regularizacion - Año  ... NaN        NaN
# 2    7       4113-007575-13            Obra Nueva  ... NaN        NaN
# 3   12       4113-016126-98               Reforma  ... NaN        NaN
# 4    3       4113-014456-00  Modificacion en Obra  ... NaN        NaN
#
#   sup_edificada V_cat_terreno V_cat_mejoras V_cat_total  V_impuestos  \
# 0           NaN           NaN           NaN         NaN          NaN
# 1           NaN           NaN           NaN         NaN          NaN
# 2           NaN           NaN           NaN         NaN          NaN
# 3           NaN           NaN           NaN         NaN          NaN
# 4           NaN           NaN           NaN         NaN          NaN
#
#    Fecha_UDJ  Vigencia_UDJ   dia
# 0        NaN           NaN  <NA>
# 1        NaN           NaN  <NA>
# 2        NaN           NaN  <NA>
# 3        NaN           NaN  <NA>
# 4        NaN           NaN  <NA>
#
# [5 rows x 26 columns]

# %%
per_cat.shape
# Out:
# (26679, 26)

# %%
# Guardar el DataFrame macheado como CSV de catastro
cat_per.to_csv('C:/Users/macar/Desktop/Archivos Python/cat_per.csv', index=False)

# %%
# Guardar el DataFrame macheado como CSV de permisos
per_cat.to_csv('C:/Users/macar/Desktop/Archivos Python/per_cat.csv', index=False)

# %%
conteo_codreg = per_cat.groupby('cod_reg').size().reset_index(name='cantidad_expedientes')

conteo_codreg
# Out:
#   cod_reg  cantidad_expedientes
# 0      CO                  1071
# 1      PH                    77

# %%
conteo_codreg['porcentaje'] = ((conteo_codreg['cantidad_expedientes'] / conteo_codreg['cantidad_expedientes'].sum()) * 100).round(2)
conteo_codreg
# Out:
#   cod_reg  cantidad_expedientes  porcentaje
# 0      CO                  1071       93.29
# 1      PH                    77        6.71

# %%
conteo_destino = per_cat.groupby('destino').size().reset_index(name='cantidades por destino')

conteo_destino
# Out:
#                                               destino  cantidades por destino
# 0   Comercio                                      ...                    4567
# 1   Comercio, Industria, Otros                    ...                       3
# 2   Comercio,Industria                            ...                      22
# 3   Comercio,Otros                                ...                     102
# 4   Desconocido                                   ...                    1468
# 5   Industria                                     ...                     828
# 6   Industria,Otros                               ...                      26
# 7   Otros                                         ...                     835
# 8   Vivienda                                      ...                   16692
# 9   Vivienda, Industria, Otros                    ...                       5
# 10  Vivienda,Comercio                             ...                     265
# 11  Vivienda,Comercio,Industria                   ...                       4
# 12  Vivienda,Comercio,Otros                       ...                     185
# 13  Vivienda,Industria                            ...                      28
# 14  Vivienda,Otros                                ...                    1649

# %%
conteo_destino['porcentaje_destino'] = ((conteo_destino['cantidades por destino'] / conteo_destino['cantidades por destino'].sum()) * 100).round(2)
conteo_destino
# Out:
#                                               destino  cantidades por destino  \
# 0   Comercio                                      ...                    4567
# 1   Comercio, Industria, Otros                    ...                       3
# 2   Comercio,Industria                            ...                      22
# 3   Comercio,Otros                                ...                     102
# 4   Desconocido                                   ...                    1468
# 5   Industria                                     ...                     828
# 6   Industria,Otros                               ...                      26
# 7   Otros                                         ...                     835
# 8   Vivienda                                      ...                   16692
# 9   Vivienda, Industria, Otros                    ...                       5
# 10  Vivienda,Comercio                             ...                     265
# 11  Vivienda,Comercio,Industria                   ...                       4
# 12  Vivienda,Comercio,Otros                       ...                     185
# 13  Vivienda,Industria                            ...                      28
# 14  Vivienda,Otros                                ...                    1649
#
#     porcentaje_destino
# 0                17.12
# 1                 0.01
# 2                 0.08
# 3                 0.38
# 4                 5.50
# 5                 3.10
# 6                 0.10
# 7                 3.13
# 8                62.57
# 9                 0.02
# 10                0.99
# 11                0.01
# 12                0.69
# 13                0.10
# 14                6.18

# %%
print(per_cat['destino'].unique())
# Out:
# ['Vivienda                                          '
#  'Comercio                                          '
#  'Vivienda,Comercio,Otros                           '
#  'Vivienda,Otros                                    '
#  'Otros                                             '
#  'Industria                                         '
#  'Desconocido                                       '
#  'Comercio,Industria                                '
#  'Vivienda,Comercio                                 '
#  'Comercio,Otros                                    '
#  'Vivienda,Industria                                '
#  'Industria,Otros                                   '
#  'Vivienda, Industria, Otros                        '
#  'Comercio, Industria, Otros                        '
#  'Vivienda,Comercio,Industria                       ']

# %%
per_cat['destino'] = per_cat['destino'].str.strip()

# %%
mapeo_destinos = {
    'Comercio': 'Actividad Empresarial',
    'Comercio, Industria, Otros': 'Actividad Empresarial',
    'Comercio,Industria': 'Actividad Empresarial',
    'Comercio,Otros': 'Actividad Empresarial',
    'Industria': 'Actividad Empresarial',
    'Industria,Otros': 'Actividad Empresarial',
    'Vivienda': 'Vivienda',
    'Vivienda, Industria, Otros': 'Vivienda',
    'Vivienda,Comercio': 'Vivienda',
    'Vivienda,Comercio,Industria': 'Vivienda',
    'Vivienda,Comercio,Otros': 'Vivienda',
    'Vivienda,Industria': 'Vivienda',
    'Vivienda,Otros': 'Vivienda',
    'Desconocido' : 'Sin destino definido',
    'Otros': 'Sin destino definido'         
}

# %%
per_cat['Nuevo_Destino'] = per_cat['destino'].map(mapeo_destinos)

# %%
per_cat.head()
# Out:
#    pad   destino    area                                              calle  \
# 0    2  Vivienda   26.00  MIGUELETE                                     ...
# 1    8  Comercio    5.00  LA PAZ                                        ...
# 2    8  Comercio  315.00  LA PAZ                                        ...
# 3    9  Vivienda   14.84  LA PAZ                                        ...
# 4   15  Vivienda   49.85  PIEDRA ALTA                                   ...
#
#    puerta  letra  anio  mes           expediente             tipo_obra  ...  \
# 0  1420.0         2000    9       4113-016778-00            Obra Nueva  ...
# 1  1439.0         2019    3  2018-4113-98-001306  Regularizacion - Año  ...
# 2  1439.0         2013    7       4113-007575-13            Obra Nueva  ...
# 3  1431.0         1998   12       4113-016126-98               Reforma  ...
# 4  1779.0         2004    3       4113-014456-00  Modificacion en Obra  ...
#
#   sup_predio sup_edificada V_cat_terreno V_cat_mejoras V_cat_total  \
# 0        NaN           NaN           NaN           NaN         NaN
# 1        NaN           NaN           NaN           NaN         NaN
# 2        NaN           NaN           NaN           NaN         NaN
# 3        NaN           NaN           NaN           NaN         NaN
# 4        NaN           NaN           NaN           NaN         NaN
#
#   V_impuestos  Fecha_UDJ  Vigencia_UDJ   dia          Nuevo_Destino
# 0         NaN        NaN           NaN  <NA>               Vivienda
# 1         NaN        NaN           NaN  <NA>  Actividad Empresarial
# 2         NaN        NaN           NaN  <NA>  Actividad Empresarial
# 3         NaN        NaN           NaN  <NA>               Vivienda
# 4         NaN        NaN           NaN  <NA>               Vivienda
#
# [5 rows x 27 columns]

# %%
print(per_cat['Nuevo_Destino'].unique())
# Out:
# ['Vivienda' 'Actividad Empresarial' 'Sin destino definido']

# %%
# Agrupar por la nueva categoría
conteo_Nuevo_Destino = per_cat.groupby('Nuevo_Destino').size().reset_index(name='cantidades por destino')
conteo_Nuevo_Destino
# Out:
#            Nuevo_Destino  cantidades por destino
# 0  Actividad Empresarial                    5548
# 1   Sin destino definido                    2303
# 2               Vivienda                   18828

# %%
conteo_Nuevo_Destino['porcentaje_Nuevo_Destino'] = ((conteo_Nuevo_Destino['cantidades por destino'] / conteo_Nuevo_Destino['cantidades por destino'].sum()) * 100).round(2)
conteo_Nuevo_Destino
# Out:
#            Nuevo_Destino  cantidades por destino  porcentaje_Nuevo_Destino
# 0  Actividad Empresarial                    5548                     20.80
# 1   Sin destino definido                    2303                      8.63
# 2               Vivienda                   18828                     70.57

# %%
conteo_tipo_obra = per_cat.groupby('tipo_obra').size().reset_index(name='cantidad por tipo de obra')
conteo_tipo_obra
# Out:
#                     tipo_obra  cantidad por tipo de obra
# 0               A regularizar                         22
# 1                  Autorizada                         79
# 2         Cielo A. Autorizada                          5
# 3                  Demolicion                         60
# 4                 Desconocido                       1109
# 5             Estacionamiento                         42
# 6                      Galpon                         49
# 7        Incorporacion A.P.H.                        748
# 8          Incorporación a PH                         15
# 9                  Marquesina                         16
# 10       Modificacion en Obra                        179
# 11                 Obra Nueva                       9553
# 12    Obra nueva / ampliación                         92
# 13                   Pilotaje                         22
# 14                  Reciclaje                         60
# 15                    Reforma                       4577
# 16      Reforma a Regularizar                        367
# 17       Regularizacion - Año                       9670
# 18  Regularización de reforma                          5
# 19                      Toldo                          9

# %%
per_cat['tipo_obra'] = per_cat['tipo_obra'].replace('Incorporacion A.P.H.', 'Incorporación a PH')

# %%
tabla_Regimen_tipoObra = pd.pivot_table(per_cat, index='tipo_obra', columns='cod_reg', aggfunc='size', fill_value=0)
tabla_Regimen_tipoObra
# Out:
# cod_reg                   CO  PH
# tipo_obra
# Demolicion                 1   0
# Desconocido                1   0
# Incorporación a PH         4   1
# Modificacion en Obra       0   1
# Obra Nueva               453  17
# Obra nueva / ampliación    1   0
# Reciclaje                  0   1
# Reforma                  281  13
# Reforma a Regularizar      3   4
# Regularizacion - Año     327  40

# %%
perm_const_ge = pd.read_excel('C:/Users/macar/Desktop/Archivos Python/v_ce_permisos_construccion_geom.xlsx')

# %%
perm_const_ge.shape
# Out:
# (40786, 15)

# %%
perm_const_ge.head(3)
# Out:
#         GID           EXPEDIENTE  FECHA_INI FECHA_APRO  MES_APRO  ANIO_APRO  \
# 0  25988748       4113-016778-00 2000-08-10 2000-09-06         9       2000
# 1  25988984  2018-4113-98-001306 2018-12-19 2019-03-06         3       2019
# 2  25988984       4113-007575-13 2013-07-03 2013-07-03         7       2013
#
#    PADRON UNIDAD            DSC_TIPO_T DSC_DESTIN            DSC_REGIME  \
# 0       2    NaN  OBRAS/CONSTRUCCIONES   Vivienda  Propiedad Horizontal
# 1       8    NaN  OBRAS/CONSTRUCCIONES   Comercio                 Común
# 2       8    NaN  OBRAS/CONSTRUCCIONES   Comercio                 Común
#
#              DSC_TIPO_O            DSC_CATEGO  CONSTRUCTOR  AREA_EDIF
# 0            Obra Nueva  Económico o Sencillo  Desconocido       26.0
# 1  Regularizacion - Año               Mediano  Desconocido        5.0
# 2            Obra Nueva               Mediano  Desconocido      315.0

# %%
perm_const_ge['FECHA_INI'] = pd.to_datetime(perm_const_ge['FECHA_INI'])
perm_const_ge['FECHA_APRO'] = pd.to_datetime(perm_const_ge['FECHA_APRO'])

# %%
perm_const_ge['T_Demora'] = (perm_const_ge['FECHA_APRO'] - perm_const_ge['FECHA_INI']).dt.days

# %%
perm_const_ge['año_ini'] = perm_const_ge['FECHA_INI'].dt.year

# %%
perm_const_ge.shape
# Out:
# (40786, 17)

# %%
perm_const_ge.head(2)
# Out:
#         GID           EXPEDIENTE  FECHA_INI FECHA_APRO  MES_APRO  ANIO_APRO  \
# 0  25988748       4113-016778-00 2000-08-10 2000-09-06         9       2000
# 1  25988984  2018-4113-98-001306 2018-12-19 2019-03-06         3       2019
#
#    PADRON UNIDAD            DSC_TIPO_T DSC_DESTIN            DSC_REGIME  \
# 0       2    NaN  OBRAS/CONSTRUCCIONES   Vivienda  Propiedad Horizontal
# 1       8    NaN  OBRAS/CONSTRUCCIONES   Comercio                 Común
#
#              DSC_TIPO_O            DSC_CATEGO  CONSTRUCTOR  AREA_EDIF  \
# 0            Obra Nueva  Económico o Sencillo  Desconocido       26.0
# 1  Regularizacion - Año               Mediano  Desconocido        5.0
#
#    T_Demora  año_ini
# 0        27     2000
# 1        77     2018

# %%
PROM_DEMORA_por_año = perm_const_ge.groupby('año_ini')['T_Demora'].mean().reset_index()

# %%
PROM_DEMORA_por_año.rename(columns={'T_Demora': 'Promedio_T_Demora'}, inplace=True)

# %%
PROM_DEMORA_por_año['Promedio_T_Demora'] = PROM_DEMORA_por_año['Promedio_T_Demora'].astype(int)

# %%
PROM_DEMORA_por_año
# Out:
#     año_ini  Promedio_T_Demora
# 0      1997                714
# 1      1998                732
# 2      1999                665
# 3      2000                700
# 4      2001                721
# 5      2002                229
# 6      2003                 37
# 7      2004                 29
# 8      2005                 25
# 9      2006                 28
# 10     2007                 30
# 11     2008                 36
# 12     2009                 33
# 13     2010                 34
# 14     2011                -14
# 15     2012                 35
# 16     2013                 33
# 17     2014                 28
# 18     2015                 34
# 19     2016                 36
# 20     2017                 43
# 21     2018                 72
# 22     2019                119
# 23     2020                 82
# 24     2021                 68
# 25     2022                 87
# 26     2023                 86
# 27     2024                106

# %%
perm_const_ge_sin_desc = perm_const_ge[perm_const_ge['DSC_CATEGO'] != 'Desconocido']

# %%
perm_const_ge_sin_desc.shape
# Out:
# (34753, 17)

# %%
conteo_por_año_apro = perm_const_ge_sin_desc.groupby('ANIO_APRO').size()

# %%
conteo_por_año_apro
# Out:
# ANIO_APRO
# 1968       1
# 1969       1
# 1975       1
# 1976       1
# 1977       1
# 1993       1
# 1997     100
# 1998    1656
# 1999    1855
# 2000    1645
# 2001    1010
# 2002    1029
# 2003    1477
# 2004    1632
# 2005    2037
# 2006    1882
# 2007    1965
# 2008    2095
# 2009    1965
# 2010    1922
# 2011    1810
# 2012    1708
# 2013    1680
# 2014    1766
# 2015    1485
# 2016     980
# 2017    1387
# 2018    1138
# 2019     456
# 2020      38
# 2021      16
# 2022       7
# 2023       5
# 2024       1
# dtype: int64
